# %% [markdown]
# ## Notebook for Data Exploration & Customer Segmentation on Customer Spend Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns

from statsmodels.stats.weightstats import ztest
pd.set_option('display.max_rows', 500)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#read the input data
data = pd.read_csv('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Input/Mall_customers.csv')

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %% [markdown]
# #### Hypothesis 1 - Spending Habits vary based on gender

# %%
#Check the data distribution by Genre
gender_list = list(data['Genre'].value_counts().index.values)
values = list(data['Genre'].value_counts().values)

# create a bar graph
plt.bar(gender_list, values,color = ['orange', 'green'])

# add title and labels
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Total Count')

# show the graph
plt.show()

# %%
#Check if there is a behavioural difference between the spendings of Male vs Female
male_spending = data[data['Genre']=='Male']['Spending_Score']
female_spending = data[data['Genre']=='Female']['Spending_Score']

# create a histogram with different groups
plt.boxplot([male_spending, female_spending], labels=['Male', 'Female'])

# add title and labels
plt.title('Spending Distribution by Gender')
plt.xlabel('Value')
plt.ylabel('Frequency')

# add legend
plt.legend()

# show the graph
plt.show()

print(data.groupby(['Genre'])['Spending_Score'].describe())
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#         count       mean       std  min   25%   50%   75%   max
# Genre
# Female  112.0  51.526786  24.11495  5.0  35.0  50.0  73.0  99.0
# Male     88.0  48.511364  27.89677  1.0  24.5  50.0  70.0  97.0

# %% [markdown]
# * Spending score for Female looks slightly higher than Male
# * Verify if this difference is statistically significant

# %%
#Is there a statistically significant difference between the spending behaviour of Male & Female
#Run a statistical analysis to test this hypothesis

#Run a 2-Sample Z-Test (2-Tailed) 
# H0: Average spending score for Male is equal to average spending score for Female
# Ha: There is a significant difference between spending habits for Male and Female

#Significance level
alpha = 0.05

# Sample data
male_spending_score = data[data['Genre']=='Male']['Spending_Score']
female_spending_score = data[data['Genre']=='Female']['Spending_Score']

# Conduct the z-test
z_score, p_value = ztest(male_spending_score, female_spending_score)

print("The Z-Score is:",z_score)
print("The P-value is:",p_value)
# Compare the p-value to the significance level
if p_value < alpha:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
    
print("There is a statistically significant difference in the spending of habits of Female and Male")
# Out:
# The Z-Score is: -0.8190464150660333
# The P-value is: 0.4127599324349568
# Fail to reject the null hypothesis
# There is a statistically significant difference in the spending of habits of Female and Male

# %% [markdown]
# ---------------------------------------------

# %% [markdown]
# #### Hypothesis 2: Spending habits vary based on Annual income

# %%
#check the correlation between Annual Income and Spending Score
corr = data['Annual_Income_(k$)'].corr(data['Spending_Score'])
print("Correlation between Annual Income & Spending Score:",corr)
#There is no correlation between Annual Income and Spending score at an overall level

#Correlation between Annual Income and Spending Score by Gender
male_data = data[data['Genre']=='Male']
male_corr_spending_annual_income = male_data['Annual_Income_(k$)'].corr(male_data['Spending_Score'])
print("Correlation between Annual Income & Spending Score for Male:",male_corr_spending_annual_income)

#Correlation between Annual Income and Spending Score by Gender
female_data = data[data['Genre']=='Female']
female_corr_spending_annual_income = female_data['Annual_Income_(k$)'].corr(female_data['Spending_Score'])
print("Correlation between Annual Income & Spending Score for Female:",female_corr_spending_annual_income)
# Out:
# Correlation between Annual Income & Spending Score: 0.009902848094037608
# Correlation between Annual Income & Spending Score for Male: -0.023684203755972282
# Correlation between Annual Income & Spending Score for Female: 0.04754211694903911

# %%
# calculate the coefficients of the linear regression
coefficients = np.polyfit(data['Annual_Income_(k$)'], data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(data['Annual_Income_(k$)'],data['Spending_Score'])

# add the regression line to the plot
plt.plot(data['Annual_Income_(k$)'], slope * data['Annual_Income_(k$)'] + intercept, color='red')
#plt.text(100, 0, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')

# add title and labels
plt.title('Income vs Spending Score')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')

# show the graph
plt.show()

print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = 0.01x + 49.61

# %%
# calculate the coefficients of the linear regression
coefficients = np.polyfit(male_data['Annual_Income_(k$)'], male_data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(male_data['Annual_Income_(k$)'],male_data['Spending_Score'],color='green')

# add the regression line to the plot
plt.plot(male_data['Annual_Income_(k$)'], slope * male_data['Annual_Income_(k$)'] + intercept, color='red')
#plt.text(100, 0, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')

# add title and labels
plt.title('Income vs Spending Score for Male')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')

# show the graph
plt.show()

print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = -0.02x + 50.05

# %%
# calculate the coefficients of the linear regression
coefficients = np.polyfit(female_data['Annual_Income_(k$)'], female_data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(female_data['Annual_Income_(k$)'],female_data['Spending_Score'],color='orange')

# add the regression line to the plot
plt.plot(female_data['Annual_Income_(k$)'], slope * female_data['Annual_Income_(k$)'] + intercept, color='red')
#plt.text(100, 2, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')

# add title and labels
plt.title('Income vs Spending Score for Male')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')

# show the graph
plt.show()

print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = 0.04x + 48.92

# %% [markdown]
# * There is no correlation between the annual income and spending score for the entire sample
# * By Gender:
# * For Male: We are observing a very marginal negative correlation between Annual Income and Spending Score
# * For Female: Whereaes, for Females, there is a very minimal positive correlation between Annual Income and Spending Score

# %% [markdown]
# #### There exsists a relationship between Spending Habit and Age

# %%
#check the correlation between Age and Spending Score
corr = data['Age'].corr(data['Spending_Score'])
print("Correlation between Age & Spending Score:",corr)
#There is no correlation between Annual Income and Spending score at an overall level

#Correlation between Annual Income and Spending Score by Gender
male_data = data[data['Genre']=='Male']
male_corr_spending_annual_income = male_data['Age'].corr(male_data['Spending_Score'])
print("Correlation between Age & Spending Score for Male:",male_corr_spending_annual_income)

#Correlation between Annual Income and Spending Score by Gender
female_data = data[data['Genre']=='Female']
female_corr_spending_annual_income = female_data['Age'].corr(female_data['Spending_Score'])
print("Correlation between Age & Spending Score for Female:",female_corr_spending_annual_income)
# Out:
# Correlation between Age & Spending Score: -0.32722684603909014
# Correlation between Age & Spending Score for Male: -0.2796276462749313
# Correlation between Age & Spending Score for Female: -0.3754385837780473

# %%
# calculate the coefficients of the linear regression

coefficients = np.polyfit(data['Age'], data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(data['Age'],data['Spending_Score'])

# add the regression line to the plot
plt.plot(data['Age'], slope * data['Age'] + intercept, color='red')
#plt.text(100, 2, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')


# add title and labels
plt.title('Age vs Spending Score')
plt.xlabel('Age')
plt.ylabel('Spending Score')

# show the graph
plt.show()

print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = -0.60x + 73.70

# %%
# calculate the coefficients of the linear regression

coefficients = np.polyfit(female_data['Age'], female_data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(female_data['Age'],female_data['Spending_Score'],color='orange')

# add the regression line to the plot
plt.plot(female_data['Age'], slope * female_data['Age'] + intercept, color='red')
#plt.text(100, 2, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')


# add title and labels
plt.title('Age vs Spending Score female')
plt.xlabel('Age')
plt.ylabel('Spending Score')

# show the graph
plt.show()
print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = -0.72x + 78.81

# %%
# calculate the coefficients of the linear regression

coefficients = np.polyfit(male_data['Age'], male_data['Spending_Score'], 1)
slope = coefficients[0]
intercept = coefficients[1]

# create the equation of the regression line
equation = np.poly1d(coefficients)
plt.scatter(male_data['Age'],male_data['Spending_Score'],color='green')

# add the regression line to the plot
plt.plot(male_data['Age'], slope * male_data['Age'] + intercept, color='red')
#plt.text(100, 2, 'y = {:.2f}x + {:.2f}'.format(slope, intercept), color='red')


# add title and labels
plt.title('Age vs Spending Score Male')
plt.xlabel('Age')
plt.ylabel('Spending Score')

# show the graph
plt.show()
print('y = {:.2f}x + {:.2f}'.format(slope, intercept))
# Out:
# y = -0.50x + 68.53

# %% [markdown]
# * There exists negative correlation between the age and spending score for the entire sample
# * Younger people spend more and as the age increases, people become more frugal and spend less
# * By Gender:
# * This behaviour is more prominent in Females incomparison to Male
# * Here is a detailed breakup by bucketing the age in bins:

# %%
####Group the Age in Bins and analyze the spending score
data['Age'].describe()
# Out:
# count    200.000000
# mean      38.850000
# std       13.969007
# min       18.000000
# 25%       28.750000
# 50%       36.000000
# 75%       49.000000
# max       70.000000
# Name: Age, dtype: float64

# %%
data['Age_bins']=pd.cut(data['Age'],bins=[18,20,25,30,35,40,45,50,55,60,65,70],right=True)

# %%
data.groupby(['Age_bins'])['Spending_Score'].describe()
# Out:
#           count       mean        std   min    25%   50%    75%   max
# Age_bins
# (18, 20]   13.0  39.923077  24.844387   5.0  10.00  49.0  55.00  75.0
# (20, 25]   21.0  63.285714  22.260150  12.0  52.00  73.0  79.00  94.0
# (25, 30]   24.0  70.666667  17.397318  40.0  54.75  73.0  83.75  97.0
# (30, 35]   36.0  60.305556  28.024295   1.0  41.50  66.0  80.75  99.0
# (35, 40]   24.0  53.291667  30.214421   1.0  30.00  51.5  78.25  95.0
# (40, 45]   12.0  27.916667  14.228386   7.0  17.00  24.0  36.00  53.0
# (45, 50]   26.0  37.384615  16.035154   5.0  26.50  42.0  47.75  59.0
# (50, 55]   11.0  35.090909  19.180483   4.0  19.00  43.0  48.00  59.0
# (55, 60]   12.0  30.166667  21.446904   4.0  13.25  25.0  49.50  60.0
# (60, 65]    5.0  36.800000  20.104726   3.0  35.00  43.0  51.00  52.0
# (65, 70]   12.0  47.250000  11.794644  14.0  45.25  49.0  55.00  59.0

# %%
data.groupby(['Age_bins','Genre'])['Spending_Score'].describe()
# Out:
#                  count       mean        std   min    25%   50%    75%   max
# Age_bins Genre
# (18, 20] Female    4.0  46.250000  28.987066   6.0  39.00  52.0  59.25  75.0
#          Male      9.0  37.111111  24.121797   5.0  10.00  46.0  55.00  66.0
# (20, 25] Female   15.0  62.666667  20.119879  29.0  47.00  65.0  77.00  94.0
#          Male      6.0  64.833333  29.061429  12.0  57.25  76.0  80.50  92.0
# (25, 30] Female   14.0  68.571429  18.533605  40.0  50.25  73.0  85.25  89.0
#          Male     10.0  73.600000  16.153431  54.0  59.00  72.0  82.75  97.0
# (30, 35] Female   23.0  62.260870  26.428665   6.0  42.00  69.0  82.50  99.0
#          Male     13.0  56.846154  31.461209   1.0  35.00  63.0  74.00  93.0
# (35, 40] Female   12.0  51.916667  23.895448  26.0  31.75  41.0  75.25  91.0
#          Male     12.0  54.666667  36.519816   1.0  13.00  65.0  88.75  95.0
# (40, 45] Female    9.0  29.222222  15.730367   7.0  17.00  28.0  39.00  53.0
#          Male      3.0  24.000000   9.643651  17.0  18.50  20.0  27.50  35.0
# (45, 50] Female   16.0  38.500000  17.084106   5.0  25.00  44.5  49.00  59.0
#          Male     10.0  35.600000  14.901156   9.0  28.50  38.5  45.00  56.0
# (50, 55] Female    7.0  37.285714  20.014281  13.0  19.00  43.0  54.00  59.0
#          Male      4.0  31.250000  19.855730   4.0  22.75  37.5  46.00  46.0
# (55, 60] Female    5.0  32.000000  21.748563   5.0  15.00  35.0  49.00  56.0
#          Male      7.0  28.857143  22.872316   4.0  12.50  15.0  49.00  60.0
# (60, 65] Female    2.0  39.000000   5.656854  35.0  37.00  39.0  41.00  43.0
#          Male      3.0  35.333333  28.005952   3.0  27.00  51.0  51.50  52.0
# (65, 70] Female    4.0  51.250000   2.986079  48.0  49.50  51.0  52.75  55.0
#          Male      8.0  45.250000  14.179966  14.0  42.50  47.0  55.25  59.0

# %%
fig = plt.figure(figsize=(14, 6))

# create a box plot using Seaborn
sns.boxplot(x='Age_bins', y='Spending_Score', data=data)

# add title and labels
plt.title('Spending Distribution by Age Buckets')
plt.xlabel('Age Bucket')
plt.ylabel('Spending Score')

# display the plot
plt.show()

# %%
#Correlation between Annual Income and Spending Score by Gender
female_data = data[data['Genre']=='Female']


fig = plt.figure(figsize=(8, 6))

# create a box plot using Seaborn
sns.boxplot(x='Age_bins', y='Spending_Score', data=female_data)

# add title and labels
plt.title('Spending Distribution by Age Buckets for Female')
plt.xlabel('Age Bucket')
plt.ylabel('Spending Score')

# display the plot
plt.show()

# %%
#Correlation between Annual Income and Spending Score by Gender
male_data = data[data['Genre']=='Male']


fig = plt.figure(figsize=(8, 6))

# create a box plot using Seaborn
sns.boxplot(x='Age_bins', y='Spending_Score', data=male_data)

# add title and labels
plt.title('Spending Distribution by Age Buckets for Male')
plt.xlabel('Age Bucket')
plt.ylabel('Spending Score')

# display the plot
plt.show()

# %%
female_data_age_bucket = female_data.groupby(['Age_bins'])['Spending_Score'].mean()
female_data_age_bucket = female_data_age_bucket.reset_index()
female_data_age_bucket['Gender']= 'Female'

male_data_age_bucket = male_data.groupby(['Age_bins'])['Spending_Score'].mean()
male_data_age_bucket = male_data_age_bucket.reset_index()
male_data_age_bucket['Gender']= 'Male'

# %%
age_bucket_spending_habit = female_data_age_bucket.append(male_data_age_bucket,ignore_index=True)
age_bucket_spending_habit
# Out:
#     Age_bins  Spending_Score  Gender
# 0   (18, 20]       46.250000  Female
# 1   (20, 25]       62.666667  Female
# 2   (25, 30]       68.571429  Female
# 3   (30, 35]       62.260870  Female
# 4   (35, 40]       51.916667  Female
# 5   (40, 45]       29.222222  Female
# 6   (45, 50]       38.500000  Female
# 7   (50, 55]       37.285714  Female
# 8   (55, 60]       32.000000  Female
# 9   (60, 65]       39.000000  Female
# 10  (65, 70]       51.250000  Female
# 11  (18, 20]       37.111111    Male
# 12  (20, 25]       64.833333    Male
# 13  (25, 30]       73.600000    Male
# 14  (30, 35]       56.846154    Male
# 15  (35, 40]       54.666667    Male
# 16  (40, 45]       24.000000    Male
# 17  (45, 50]       35.600000    Male
# 18  (50, 55]       31.250000    Male
# 19  (55, 60]       28.857143    Male
# 20  (60, 65]       35.333333    Male
# 21  (65, 70]       45.250000    Male

# %% [markdown]
# #### Clustering Excercise

# %% [markdown]
# * To Analyze the overall behaviour on spendings,
# * we are going to find inherent patterns within the data by using K-Means clustering

# %%
clustering_dataset = data.loc[:,['CustomerID','Genre','Age','Annual_Income_(k$)','Spending_Score']]

gender_map ={'Male':0,'Female':1}
clustering_dataset['Gender']=clustering_dataset['Genre'].map(gender_map)

# %%
clustering_dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  Gender
# 0           1    Male   19                  15              39       0
# 1           2    Male   21                  15              81       0
# 2           3  Female   20                  16               6       1
# 3           4  Female   23                  16              77       1
# 4           5  Female   31                  17              40       1

# %%
#write a code to scale the variables so all the datapoints are weighted equally
from sklearn.preprocessing import StandardScaler


variables_to_scale = ['Age','Annual_Income_(k$)','Spending_Score']
# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the dataset
scaler.fit(clustering_dataset[variables_to_scale])

# Transform the dataset to standardized values
X_std = scaler.transform(clustering_dataset[variables_to_scale])


Age_scaled = X_std[:,0]
Annual_income_scaled = X_std[:,1]
Spending_score_scaled = X_std[:,2]

clustering_dataset['Age_scaled'] = Age_scaled
clustering_dataset['Annual_income_scaled'] = Annual_income_scaled
clustering_dataset['Spending_score_scaled'] = Spending_score_scaled

# %%
clustering_dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  Gender  \
# 0           1    Male   19                  15              39       0
# 1           2    Male   21                  15              81       0
# 2           3  Female   20                  16               6       1
# 3           4  Female   23                  16              77       1
# 4           5  Female   31                  17              40       1
#
#    Age_scaled  Annual_income_scaled  Spending_score_scaled
# 0   -1.424569             -1.738999              -0.434801
# 1   -1.281035             -1.738999               1.195704
# 2   -1.352802             -1.700830              -1.715913
# 3   -1.137502             -1.700830               1.040418
# 4   -0.563369             -1.662660              -0.395980

# %%
# Rescale the standardized dataset back to the original range
# X_rescaled = scaler.inverse_transform(X_std)

# # Print the rescaled dataset
# print(X_rescaled)

# %%
#clutering columns
clustering_columns=['Age','Age_scaled','Annual_income_scaled','Spending_score_scaled']

# %%
# calculate the within-cluster sum of squares for different values of K
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init="k-means++", max_iter=300, n_init=10, random_state=0)
    kmeans.fit(clustering_dataset[clustering_columns])
    wcss.append(kmeans.inertia_)

# plot the within-cluster sum of squares as a function of K
plt.plot(range(1, 11), wcss)
plt.title("Optimal Cluster Selection with Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("Within-Cluster Sum of Squares")
plt.show()

# %% [markdown]
# * From Visual Inspection it is observed that Optimal value of K can be selected as 2, 3 or 4 as that is where the elbow is formed

# %%
#Based on Elbow curve visual, 4 appears to be optimal number of clusters
#Starting with K=4

optimal_k=4

kmeans = KMeans(n_clusters=optimal_k, init="k-means++", max_iter=300, n_init=10, random_state=0)
cluster_labels = kmeans.fit_predict(clustering_dataset[clustering_columns])

clustering_dataset['Cluster_label'] = cluster_labels

# %%
clustering_dataset['Cluster_label'].value_counts()
# Out:
# 0    74
# 3    50
# 2    47
# 1    29
# Name: Cluster_label, dtype: int64

# %%
clustering_dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  Gender  \
# 0           1    Male   19                  15              39       0
# 1           2    Male   21                  15              81       0
# 2           3  Female   20                  16               6       1
# 3           4  Female   23                  16              77       1
# 4           5  Female   31                  17              40       1
#
#    Age_scaled  Annual_income_scaled  Spending_score_scaled  Cluster_label
# 0   -1.424569             -1.738999              -0.434801              3
# 1   -1.281035             -1.738999               1.195704              3
# 2   -1.352802             -1.700830              -1.715913              3
# 3   -1.137502             -1.700830               1.040418              3
# 4   -0.563369             -1.662660              -0.395980              0

# %%
clustering_dataset.groupby(['Cluster_label'])['Spending_Score'].describe()
# Out:
#                count       mean        std  min    25%   50%   75%   max
# Cluster_label
# 0               74.0  60.148649  28.221571  1.0  40.00  71.5  84.5  99.0
# 1               29.0  38.379310  18.872531  3.0  15.00  47.0  52.0  60.0
# 2               47.0  34.829787  16.643734  4.0  18.50  41.0  47.5  59.0
# 3               50.0  56.780000  23.561721  5.0  46.25  55.0  75.0  97.0

# %%
clustering_dataset.groupby(['Cluster_label'])['Age'].describe()
# Out:
#                count       mean       std   min   25%   50%   75%   max
# Cluster_label
# 0               74.0  34.229730  3.505562  29.0  31.0  34.0  37.0  41.0
# 1               29.0  63.275862  4.471310  56.0  59.0  64.0  67.0  70.0
# 2               47.0  48.340426  3.421648  42.0  46.0  48.0  50.0  55.0
# 3               50.0  22.600000  3.251373  18.0  20.0  22.5  25.0  28.0

# %%
clustering_dataset.groupby(['Cluster_label'])['Annual_Income_(k$)'].describe()
# Out:
#                count       mean        std   min    25%   50%   75%    max
# Cluster_label
# 0               74.0  69.878378  29.944219  17.0  44.25  74.5  87.0  137.0
# 1               29.0  53.689655  18.384977  19.0  46.00  54.0  63.0   93.0
# 2               47.0  59.829787  23.303591  23.0  43.00  58.0  72.0  126.0
# 3               50.0  51.440000  22.766929  15.0  33.00  55.5  66.5  101.0

# %%
cluster_by_gender = clustering_dataset.groupby(['Cluster_label'])['Genre'].value_counts()
print(cluster_by_gender)
# Out:
# Cluster_label  Genre
# 0              Female    46
#                Male      28
# 1              Male      18
#                Female    11
# 2              Female    30
#                Male      17
# 3              Female    25
#                Male      25
# Name: Genre, dtype: int64

# %%
#Create cluster profile mapping
cluster_map = {0:'Extravagant_Spending_Adults '
               ,1:'Modest_Spending_Seniors'
               ,2:'Middle_Aged_low_Spenders'
               ,3:'High_Spending_Youth'}

clustering_dataset['Cluster_name']= clustering_dataset['Cluster_label'].map(cluster_map)

# %%
clustering_dataset.groupby(['Cluster_name'])['Spending_Score'].describe()
# Out:
#                               count       mean        std  min    25%   50%  \
# Cluster_name
# Extravagant_Spending_Adults    74.0  60.148649  28.221571  1.0  40.00  71.5
# High_Spending_Youth            50.0  56.780000  23.561721  5.0  46.25  55.0
# Middle_Aged_low_Spenders       47.0  34.829787  16.643734  4.0  18.50  41.0
# Modest_Spending_Seniors        29.0  38.379310  18.872531  3.0  15.00  47.0
#
#                                75%   max
# Cluster_name
# Extravagant_Spending_Adults   84.5  99.0
# High_Spending_Youth           75.0  97.0
# Middle_Aged_low_Spenders      47.5  59.0
# Modest_Spending_Seniors       52.0  60.0

# %%
clustering_dataset.groupby(['Cluster_name'])['Age'].describe()
# Out:
#                               count       mean       std   min   25%   50%  \
# Cluster_name
# Extravagant_Spending_Adults    74.0  34.229730  3.505562  29.0  31.0  34.0
# High_Spending_Youth            50.0  22.600000  3.251373  18.0  20.0  22.5
# Middle_Aged_low_Spenders       47.0  48.340426  3.421648  42.0  46.0  48.0
# Modest_Spending_Seniors        29.0  63.275862  4.471310  56.0  59.0  64.0
#
#                                75%   max
# Cluster_name
# Extravagant_Spending_Adults   37.0  41.0
# High_Spending_Youth           25.0  28.0
# Middle_Aged_low_Spenders      50.0  55.0
# Modest_Spending_Seniors       67.0  70.0

# %%
clustering_dataset.groupby(['Cluster_name'])['Annual_Income_(k$)'].describe()
# Out:
#                               count       mean        std   min    25%   50%  \
# Cluster_name
# Extravagant_Spending_Adults    74.0  69.878378  29.944219  17.0  44.25  74.5
# High_Spending_Youth            50.0  51.440000  22.766929  15.0  33.00  55.5
# Middle_Aged_low_Spenders       47.0  59.829787  23.303591  23.0  43.00  58.0
# Modest_Spending_Seniors        29.0  53.689655  18.384977  19.0  46.00  54.0
#
#                                75%    max
# Cluster_name
# Extravagant_Spending_Adults   87.0  137.0
# High_Spending_Youth           66.5  101.0
# Middle_Aged_low_Spenders      72.0  126.0
# Modest_Spending_Seniors       63.0   93.0

# %%
clustering_dataset.groupby(['Cluster_name'])['Genre'].value_counts()
# Out:
# Cluster_name                  Genre
# Extravagant_Spending_Adults   Female    46
#                               Male      28
# High_Spending_Youth           Female    25
#                               Male      25
# Middle_Aged_low_Spenders      Female    30
#                               Male      17
# Modest_Spending_Seniors       Male      18
#                               Female    11
# Name: Genre, dtype: int64

# %%
clustering_dataset
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score  Gender  \
# 0             1    Male   19                  15              39       0
# 1             2    Male   21                  15              81       0
# 2             3  Female   20                  16               6       1
# 3             4  Female   23                  16              77       1
# 4             5  Female   31                  17              40       1
# 5             6  Female   22                  17              76       1
# 6             7  Female   35                  18               6       1
# 7             8  Female   23                  18              94       1
# 8             9    Male   64                  19               3       0
# 9            10  Female   30                  19              72       1
# 10           11    Male   67                  19              14       0
# 11           12  Female   35                  19              99       1
# 12           13  Female   58                  20              15       1
# 13           14  Female   24                  20              77       1
# 14           15    Male   37                  20              13       0
# 15           16    Male   22                  20              79       0
# 16           17  Female   35                  21              35       1
# 17           18    Male   20                  21              66       0
# 18           19    Male   52                  23              29       0
# 19           20  Female   35                  23              98       1
# 20           21    Male   35                  24              35       0
# 21           22    Male   25                  24              73       0
# 22           23  Female   46                  25               5       1
# 23           24    Male   31                  25              73       0
# 24           25  Female   54                  28              14       1
# 25           26    Male   29                  28              82       0
# 26           27  Female   45                  28              32       1
# 27           28    Male   35                  28              61       0
# 28           29  Female   40                  29              31       1
# 29           30  Female   23                  29              87       1
# 30           31    Male   60                  30               4       0
# 31           32  Female   21                  30              73       1
# 32           33    Male   53                  33               4       0
# 33           34    Male   18                  33              92       0
# 34           35  Female   49                  33              14       1
# 35           36  Female   21                  33              81       1
# 36           37  Female   42                  34              17       1
# 37           38  Female   30                  34              73       1
# 38           39  Female   36                  37              26       1
# 39           40  Female   20                  37              75       1
# 40           41  Female   65                  38              35       1
# 41           42    Male   24                  38              92       0
# 42           43    Male   48                  39              36       0
# 43           44  Female   31                  39              61       1
# 44           45  Female   49                  39              28       1
# 45           46  Female   24                  39              65       1
# 46           47  Female   50                  40              55       1
# 47           48  Female   27                  40              47       1
# 48           49  Female   29                  40              42       1
# 49           50  Female   31                  40              42       1
# 50           51  Female   49                  42              52       1
# 51           52    Male   33                  42              60       0
# 52           53  Female   31                  43              54       1
# 53           54    Male   59                  43              60       0
# 54           55  Female   50                  43              45       1
# 55           56    Male   47                  43              41       0
# 56           57  Female   51                  44              50       1
# 57           58    Male   69                  44              46       0
# 58           59  Female   27                  46              51       1
# 59           60    Male   53                  46              46       0
# 60           61    Male   70                  46              56       0
# 61           62    Male   19                  46              55       0
# 62           63  Female   67                  47              52       1
# 63           64  Female   54                  47              59       1
# 64           65    Male   63                  48              51       0
# 65           66    Male   18                  48              59       0
# 66           67  Female   43                  48              50       1
# 67           68  Female   68                  48              48       1
# 68           69    Male   19                  48              59       0
# 69           70  Female   32                  48              47       1
# 70           71    Male   70                  49              55       0
# 71           72  Female   47                  49              42       1
# 72           73  Female   60                  50              49       1
# 73           74  Female   60                  50              56       1
# 74           75    Male   59                  54              47       0
# 75           76    Male   26                  54              54       0
# 76           77  Female   45                  54              53       1
# 77           78    Male   40                  54              48       0
# 78           79  Female   23                  54              52       1
# 79           80  Female   49                  54              42       1
# 80           81    Male   57                  54              51       0
# 81           82    Male   38                  54              55       0
# 82           83    Male   67                  54              41       0
# 83           84  Female   46                  54              44       1
# 84           85  Female   21                  54              57       1
# 85           86    Male   48                  54              46       0
# 86           87  Female   55                  57              58       1
# 87           88  Female   22                  57              55       1
# 88           89  Female   34                  58              60       1
# 89           90  Female   50                  58              46       1
# 90           91  Female   68                  59              55       1
# 91           92    Male   18                  59              41       0
# 92           93    Male   48                  60              49       0
# 93           94  Female   40                  60              40       1
# 94           95  Female   32                  60              42       1
# 95           96    Male   24                  60              52       0
# 96           97  Female   47                  60              47       1
# 97           98  Female   27                  60              50       1
# 98           99    Male   48                  61              42       0
# 99          100    Male   20                  61              49       0
# 100         101  Female   23                  62              41       1
# 101         102  Female   49                  62              48       1
# 102         103    Male   67                  62              59       0
# 103         104    Male   26                  62              55       0
# 104         105    Male   49                  62              56       0
# 105         106  Female   21                  62              42       1
# 106         107  Female   66                  63              50       1
# 107         108    Male   54                  63              46       0
# 108         109    Male   68                  63              43       0
# 109         110    Male   66                  63              48       0
# 110         111    Male   65                  63              52       0
# 111         112  Female   19                  63              54       1
# 112         113  Female   38                  64              42       1
# 113         114    Male   19                  64              46       0
# 114         115  Female   18                  65              48       1
# 115         116  Female   19                  65              50       1
# 116         117  Female   63                  65              43       1
# 117         118  Female   49                  65              59       1
# 118         119  Female   51                  67              43       1
# 119         120  Female   50                  67              57       1
# 120         121    Male   27                  67              56       0
# 121         122  Female   38                  67              40       1
# 122         123  Female   40                  69              58       1
# 123         124    Male   39                  69              91       0
# 124         125  Female   23                  70              29       1
# 125         126  Female   31                  70              77       1
# 126         127    Male   43                  71              35       0
# 127         128    Male   40                  71              95       0
# 128         129    Male   59                  71              11       0
# 129         130    Male   38                  71              75       0
# 130         131    Male   47                  71               9       0
# 131         132    Male   39                  71              75       0
# 132         133  Female   25                  72              34       1
# 133         134  Female   31                  72              71       1
# 134         135    Male   20                  73               5       0
# 135         136  Female   29                  73              88       1
# 136         137  Female   44                  73               7       1
# 137         138    Male   32                  73              73       0
# 138         139    Male   19                  74              10       0
# 139         140  Female   35                  74              72       1
# 140         141  Female   57                  75               5       1
# 141         142    Male   32                  75              93       0
# 142         143  Female   28                  76              40       1
# 143         144  Female   32                  76              87       1
# 144         145    Male   25                  77              12       0
# 145         146    Male   28                  77              97       0
# 146         147    Male   48                  77              36       0
# 147         148  Female   32                  77              74       1
# 148         149  Female   34                  78              22       1
# 149         150    Male   34                  78              90       0
# 150         151    Male   43                  78              17       0
# 151         152    Male   39                  78              88       0
# 152         153  Female   44                  78              20       1
# 153         154  Female   38                  78              76       1
# 154         155  Female   47                  78              16       1
# 155         156  Female   27                  78              89       1
# 156         157    Male   37                  78               1       0
# 157         158  Female   30                  78              78       1
# 158         159    Male   34                  78               1       0
# 159         160  Female   30                  78              73       1
# 160         161  Female   56                  79              35       1
# 161         162  Female   29                  79              83       1
# 162         163    Male   19                  81               5       0
# 163         164  Female   31                  81              93       1
# 164         165    Male   50                  85              26       0
# 165         166  Female   36                  85              75       1
# 166         167    Male   42                  86              20       0
# 167         168  Female   33                  86              95       1
# 168         169  Female   36                  87              27       1
# 169         170    Male   32                  87              63       0
# 170         171    Male   40                  87              13       0
# 171         172    Male   28                  87              75       0
# 172         173    Male   36                  87              10       0
# 173         174    Male   36                  87              92       0
# 174         175  Female   52                  88              13       1
# 175         176  Female   30                  88              86       1
# 176         177    Male   58                  88              15       0
# 177         178    Male   27                  88              69       0
# 178         179    Male   59                  93              14       0
# 179         180    Male   35                  93              90       0
# 180         181  Female   37                  97              32       1
# 181         182  Female   32                  97              86       1
# 182         183    Male   46                  98              15       0
# 183         184  Female   29                  98              88       1
# 184         185  Female   41                  99              39       1
# 185         186    Male   30                  99              97       0
# 186         187  Female   54                 101              24       1
# 187         188    Male   28                 101              68       0
# 188         189  Female   41                 103              17       1
# 189         190  Female   36                 103              85       1
# 190         191  Female   34                 103              23       1
# 191         192  Female   32                 103              69       1
# 192         193    Male   33                 113               8       0
# 193         194  Female   38                 113              91       1
# 194         195  Female   47                 120              16       1
# 195         196  Female   35                 120              79       1
# 196         197  Female   45                 126              28       1
# 197         198    Male   32                 126              74       0
# 198         199    Male   32                 137              18       0
# 199         200    Male   30                 137              83       0
#
#      Age_scaled  Annual_income_scaled  Spending_score_scaled  Cluster_label  \
# 0     -1.424569             -1.738999              -0.434801              3
# 1     -1.281035             -1.738999               1.195704              3
# 2     -1.352802             -1.700830              -1.715913              3
# 3     -1.137502             -1.700830               1.040418              3
# 4     -0.563369             -1.662660              -0.395980              0
# 5     -1.209269             -1.662660               1.001596              3
# 6     -0.276302             -1.624491              -1.715913              0
# 7     -1.137502             -1.624491               1.700384              3
# 8      1.804932             -1.586321              -1.832378              1
# 9     -0.635135             -1.586321               0.846310              0
# 10     2.020232             -1.586321              -1.405340              1
# 11    -0.276302             -1.586321               1.894492              0
# 12     1.374332             -1.548152              -1.366519              1
# 13    -1.065735             -1.548152               1.040418              3
# 14    -0.132768             -1.548152              -1.444162              0
# 15    -1.209269             -1.548152               1.118061              3
# 16    -0.276302             -1.509983              -0.590088              0
# 17    -1.352802             -1.509983               0.613381              3
# 18     0.943732             -1.433644              -0.823017              2
# 19    -0.276302             -1.433644               1.855671              0
# 20    -0.276302             -1.395474              -0.590088              0
# 21    -0.993969             -1.395474               0.885132              3
# 22     0.513132             -1.357305              -1.754735              2
# 23    -0.563369             -1.357305               0.885132              0
# 24     1.087265             -1.242797              -1.405340              2
# 25    -0.706902             -1.242797               1.234526              0
# 26     0.441365             -1.242797              -0.706552              2
# 27    -0.276302             -1.242797               0.419273              0
# 28     0.082532             -1.204627              -0.745374              0
# 29    -1.137502             -1.204627               1.428633              3
# 30     1.517865             -1.166458              -1.793556              1
# 31    -1.281035             -1.166458               0.885132              3
# 32     1.015499             -1.051949              -1.793556              2
# 33    -1.496335             -1.051949               1.622741              3
# 34     0.728432             -1.051949              -1.405340              2
# 35    -1.281035             -1.051949               1.195704              3
# 36     0.226065             -1.013780              -1.288876              2
# 37    -0.635135             -1.013780               0.885132              0
# 38    -0.204535             -0.899272              -0.939482              0
# 39    -1.352802             -0.899272               0.962775              3
# 40     1.876699             -0.861102              -0.590088              1
# 41    -1.065735             -0.861102               1.622741              3
# 42     0.656665             -0.822933              -0.551266              2
# 43    -0.563369             -0.822933               0.419273              0
# 44     0.728432             -0.822933              -0.861839              2
# 45    -1.065735             -0.822933               0.574559              3
# 46     0.800199             -0.784763               0.186343              2
# 47    -0.850435             -0.784763              -0.124229              3
# 48    -0.706902             -0.784763              -0.318337              0
# 49    -0.563369             -0.784763              -0.318337              0
# 50     0.728432             -0.708425               0.069879              2
# 51    -0.419835             -0.708425               0.380451              0
# 52    -0.563369             -0.670255               0.147522              0
# 53     1.446099             -0.670255               0.380451              1
# 54     0.800199             -0.670255              -0.201872              2
# 55     0.584899             -0.670255              -0.357158              2
# 56     0.871965             -0.632086              -0.007764              2
# 57     2.163766             -0.632086              -0.163051              1
# 58    -0.850435             -0.555747               0.031057              3
# 59     1.015499             -0.555747              -0.163051              2
# 60     2.235532             -0.555747               0.225165              1
# 61    -1.424569             -0.555747               0.186343              3
# 62     2.020232             -0.517577               0.069879              1
# 63     1.087265             -0.517577               0.341630              2
# 64     1.733166             -0.479408               0.031057              1
# 65    -1.496335             -0.479408               0.341630              3
# 66     0.297832             -0.479408              -0.007764              2
# 67     2.091999             -0.479408              -0.085407              1
# 68    -1.424569             -0.479408               0.341630              3
# 69    -0.491602             -0.479408              -0.124229              0
# 70     2.235532             -0.441239               0.186343              1
# 71     0.584899             -0.441239              -0.318337              2
# 72     1.517865             -0.403069              -0.046586              1
# 73     1.517865             -0.403069               0.225165              1
# 74     1.446099             -0.250391              -0.124229              1
# 75    -0.922202             -0.250391               0.147522              3
# 76     0.441365             -0.250391               0.108700              2
# 77     0.082532             -0.250391              -0.085407              0
# 78    -1.137502             -0.250391               0.069879              3
# 79     0.728432             -0.250391              -0.318337              2
# 80     1.302565             -0.250391               0.031057              1
# 81    -0.061002             -0.250391               0.186343              0
# 82     2.020232             -0.250391              -0.357158              1
# 83     0.513132             -0.250391              -0.240694              2
# 84    -1.281035             -0.250391               0.263987              3
# 85     0.656665             -0.250391              -0.163051              2
# 86     1.159032             -0.135883               0.302808              2
# 87    -1.209269             -0.135883               0.186343              3
# 88    -0.348068             -0.097714               0.380451              0
# 89     0.800199             -0.097714              -0.163051              2
# 90     2.091999             -0.059544               0.186343              1
# 91    -1.496335             -0.059544              -0.357158              3
# 92     0.656665             -0.021375              -0.046586              2
# 93     0.082532             -0.021375              -0.395980              0
# 94    -0.491602             -0.021375              -0.318337              0
# 95    -1.065735             -0.021375               0.069879              3
# 96     0.584899             -0.021375              -0.124229              2
# 97    -0.850435             -0.021375              -0.007764              3
# 98     0.656665              0.016795              -0.318337              2
# 99    -1.352802              0.016795              -0.046586              3
# 100   -1.137502              0.054964              -0.357158              3
# 101    0.728432              0.054964              -0.085407              2
# 102    2.020232              0.054964               0.341630              1
# 103   -0.922202              0.054964               0.186343              3
# 104    0.728432              0.054964               0.225165              2
# 105   -1.281035              0.054964              -0.318337              3
# 106    1.948466              0.093133              -0.007764              1
# 107    1.087265              0.093133              -0.163051              2
# 108    2.091999              0.093133              -0.279515              1
# 109    1.948466              0.093133              -0.085407              1
# 110    1.876699              0.093133               0.069879              1
# 111   -1.424569              0.093133               0.147522              3
# 112   -0.061002              0.131303              -0.318337              0
# 113   -1.424569              0.131303              -0.163051              3
# 114   -1.496335              0.169472              -0.085407              3
# 115   -1.424569              0.169472              -0.007764              3
# 116    1.733166              0.169472              -0.279515              1
# 117    0.728432              0.169472               0.341630              2
# 118    0.871965              0.245811              -0.279515              2
# 119    0.800199              0.245811               0.263987              2
# 120   -0.850435              0.245811               0.225165              3
# 121   -0.061002              0.245811              -0.395980              0
# 122    0.082532              0.322150               0.302808              0
# 123    0.010765              0.322150               1.583920              0
# 124   -1.137502              0.360319              -0.823017              3
# 125   -0.563369              0.360319               1.040418              0
# 126    0.297832              0.398489              -0.590088              2
# 127    0.082532              0.398489               1.739206              0
# 128    1.446099              0.398489              -1.521805              1
# 129   -0.061002              0.398489               0.962775              0
# 130    0.584899              0.398489              -1.599448              2
# 131    0.010765              0.398489               0.962775              0
# 132   -0.993969              0.436658              -0.628909              3
# 133   -0.563369              0.436658               0.807488              0
# 134   -1.352802              0.474828              -1.754735              3
# 135   -0.706902              0.474828               1.467455              0
# 136    0.369598              0.474828              -1.677091              2
# 137   -0.491602              0.474828               0.885132              0
# 138   -1.424569              0.512997              -1.560627              3
# 139   -0.276302              0.512997               0.846310              0
# 140    1.302565              0.551167              -1.754735              1
# 141   -0.491602              0.551167               1.661563              0
# 142   -0.778669              0.589336              -0.395980              3
# 143   -0.491602              0.589336               1.428633              0
# 144   -0.993969              0.627505              -1.482984              3
# 145   -0.778669              0.627505               1.816849              3
# 146    0.656665              0.627505              -0.551266              2
# 147   -0.491602              0.627505               0.923953              0
# 148   -0.348068              0.665675              -1.094768              0
# 149   -0.348068              0.665675               1.545098              0
# 150    0.297832              0.665675              -1.288876              2
# 151    0.010765              0.665675               1.467455              0
# 152    0.369598              0.665675              -1.172411              2
# 153   -0.061002              0.665675               1.001596              0
# 154    0.584899              0.665675              -1.327697              2
# 155   -0.850435              0.665675               1.506277              3
# 156   -0.132768              0.665675              -1.910021              0
# 157   -0.635135              0.665675               1.079239              0
# 158   -0.348068              0.665675              -1.910021              0
# 159   -0.635135              0.665675               0.885132              0
# 160    1.230799              0.703844              -0.590088              1
# 161   -0.706902              0.703844               1.273347              0
# 162   -1.424569              0.780183              -1.754735              3
# 163   -0.563369              0.780183               1.661563              0
# 164    0.800199              0.932861              -0.939482              2
# 165   -0.204535              0.932861               0.962775              0
# 166    0.226065              0.971030              -1.172411              2
# 167   -0.419835              0.971030               1.739206              0
# 168   -0.204535              1.009200              -0.900660              0
# 169   -0.491602              1.009200               0.496916              0
# 170    0.082532              1.009200              -1.444162              0
# 171   -0.778669              1.009200               0.962775              3
# 172   -0.204535              1.009200              -1.560627              0
# 173   -0.204535              1.009200               1.622741              0
# 174    0.943732              1.047369              -1.444162              2
# 175   -0.635135              1.047369               1.389812              0
# 176    1.374332              1.047369              -1.366519              1
# 177   -0.850435              1.047369               0.729845              3
# 178    1.446099              1.238216              -1.405340              1
# 179   -0.276302              1.238216               1.545098              0
# 180   -0.132768              1.390894              -0.706552              0
# 181   -0.491602              1.390894               1.389812              0
# 182    0.513132              1.429063              -1.366519              2
# 183   -0.706902              1.429063               1.467455              0
# 184    0.154298              1.467233              -0.434801              0
# 185   -0.635135              1.467233               1.816849              0
# 186    1.087265              1.543572              -1.017125              2
# 187   -0.778669              1.543572               0.691024              3
# 188    0.154298              1.619911              -1.288876              0
# 189   -0.204535              1.619911               1.350990              0
# 190   -0.348068              1.619911              -1.055946              0
# 191   -0.491602              1.619911               0.729845              0
# 192   -0.419835              2.001605              -1.638270              0
# 193   -0.061002              2.001605               1.583920              0
# 194    0.584899              2.268791              -1.327697              2
# 195   -0.276302              2.268791               1.118061              0
# 196    0.441365              2.497807              -0.861839              2
# 197   -0.491602              2.497807               0.923953              0
# 198   -0.491602              2.917671              -1.250054              0
# 199   -0.635135              2.917671               1.273347              0
#
#                      Cluster_name
# 0             High_Spending_Youth
# 1             High_Spending_Youth
# 2             High_Spending_Youth
# 3             High_Spending_Youth
# 4    Extravagant_Spending_Adults
# 5             High_Spending_Youth
# 6    Extravagant_Spending_Adults
# 7             High_Spending_Youth
# 8         Modest_Spending_Seniors
# 9    Extravagant_Spending_Adults
# 10        Modest_Spending_Seniors
# 11   Extravagant_Spending_Adults
# 12        Modest_Spending_Seniors
# 13            High_Spending_Youth
# 14   Extravagant_Spending_Adults
# 15            High_Spending_Youth
# 16   Extravagant_Spending_Adults
# 17            High_Spending_Youth
# 18       Middle_Aged_low_Spenders
# 19   Extravagant_Spending_Adults
# 20   Extravagant_Spending_Adults
# 21            High_Spending_Youth
# 22       Middle_Aged_low_Spenders
# 23   Extravagant_Spending_Adults
# 24       Middle_Aged_low_Spenders
# 25   Extravagant_Spending_Adults
# 26       Middle_Aged_low_Spenders
# 27   Extravagant_Spending_Adults
# 28   Extravagant_Spending_Adults
# 29            High_Spending_Youth
# 30        Modest_Spending_Seniors
# 31            High_Spending_Youth
# 32       Middle_Aged_low_Spenders
# 33            High_Spending_Youth
# 34       Middle_Aged_low_Spenders
# 35            High_Spending_Youth
# 36       Middle_Aged_low_Spenders
# 37   Extravagant_Spending_Adults
# 38   Extravagant_Spending_Adults
# 39            High_Spending_Youth
# 40        Modest_Spending_Seniors
# 41            High_Spending_Youth
# 42       Middle_Aged_low_Spenders
# 43   Extravagant_Spending_Adults
# 44       Middle_Aged_low_Spenders
# 45            High_Spending_Youth
# 46       Middle_Aged_low_Spenders
# 47            High_Spending_Youth
# 48   Extravagant_Spending_Adults
# 49   Extravagant_Spending_Adults
# 50       Middle_Aged_low_Spenders
# 51   Extravagant_Spending_Adults
# 52   Extravagant_Spending_Adults
# 53        Modest_Spending_Seniors
# 54       Middle_Aged_low_Spenders
# 55       Middle_Aged_low_Spenders
# 56       Middle_Aged_low_Spenders
# 57        Modest_Spending_Seniors
# 58            High_Spending_Youth
# 59       Middle_Aged_low_Spenders
# 60        Modest_Spending_Seniors
# 61            High_Spending_Youth
# 62        Modest_Spending_Seniors
# 63       Middle_Aged_low_Spenders
# 64        Modest_Spending_Seniors
# 65            High_Spending_Youth
# 66       Middle_Aged_low_Spenders
# 67        Modest_Spending_Seniors
# 68            High_Spending_Youth
# 69   Extravagant_Spending_Adults
# 70        Modest_Spending_Seniors
# 71       Middle_Aged_low_Spenders
# 72        Modest_Spending_Seniors
# 73        Modest_Spending_Seniors
# 74        Modest_Spending_Seniors
# 75            High_Spending_Youth
# 76       Middle_Aged_low_Spenders
# 77   Extravagant_Spending_Adults
# 78            High_Spending_Youth
# 79       Middle_Aged_low_Spenders
# 80        Modest_Spending_Seniors
# 81   Extravagant_Spending_Adults
# 82        Modest_Spending_Seniors
# 83       Middle_Aged_low_Spenders
# 84            High_Spending_Youth
# 85       Middle_Aged_low_Spenders
# 86       Middle_Aged_low_Spenders
# 87            High_Spending_Youth
# 88   Extravagant_Spending_Adults
# 89       Middle_Aged_low_Spenders
# 90        Modest_Spending_Seniors
# 91            High_Spending_Youth
# 92       Middle_Aged_low_Spenders
# 93   Extravagant_Spending_Adults
# 94   Extravagant_Spending_Adults
# 95            High_Spending_Youth
# 96       Middle_Aged_low_Spenders
# 97            High_Spending_Youth
# 98       Middle_Aged_low_Spenders
# 99            High_Spending_Youth
# 100           High_Spending_Youth
# 101      Middle_Aged_low_Spenders
# 102       Modest_Spending_Seniors
# 103           High_Spending_Youth
# 104      Middle_Aged_low_Spenders
# 105           High_Spending_Youth
# 106       Modest_Spending_Seniors
# 107      Middle_Aged_low_Spenders
# 108       Modest_Spending_Seniors
# 109       Modest_Spending_Seniors
# 110       Modest_Spending_Seniors
# 111           High_Spending_Youth
# 112  Extravagant_Spending_Adults
# 113           High_Spending_Youth
# 114           High_Spending_Youth
# 115           High_Spending_Youth
# 116       Modest_Spending_Seniors
# 117      Middle_Aged_low_Spenders
# 118      Middle_Aged_low_Spenders
# 119      Middle_Aged_low_Spenders
# 120           High_Spending_Youth
# 121  Extravagant_Spending_Adults
# 122  Extravagant_Spending_Adults
# 123  Extravagant_Spending_Adults
# 124           High_Spending_Youth
# 125  Extravagant_Spending_Adults
# 126      Middle_Aged_low_Spenders
# 127  Extravagant_Spending_Adults
# 128       Modest_Spending_Seniors
# 129  Extravagant_Spending_Adults
# 130      Middle_Aged_low_Spenders
# 131  Extravagant_Spending_Adults
# 132           High_Spending_Youth
# 133  Extravagant_Spending_Adults
# 134           High_Spending_Youth
# 135  Extravagant_Spending_Adults
# 136      Middle_Aged_low_Spenders
# 137  Extravagant_Spending_Adults
# 138           High_Spending_Youth
# 139  Extravagant_Spending_Adults
# 140       Modest_Spending_Seniors
# 141  Extravagant_Spending_Adults
# 142           High_Spending_Youth
# 143  Extravagant_Spending_Adults
# 144           High_Spending_Youth
# 145           High_Spending_Youth
# 146      Middle_Aged_low_Spenders
# 147  Extravagant_Spending_Adults
# 148  Extravagant_Spending_Adults
# 149  Extravagant_Spending_Adults
# 150      Middle_Aged_low_Spenders
# 151  Extravagant_Spending_Adults
# 152      Middle_Aged_low_Spenders
# 153  Extravagant_Spending_Adults
# 154      Middle_Aged_low_Spenders
# 155           High_Spending_Youth
# 156  Extravagant_Spending_Adults
# 157  Extravagant_Spending_Adults
# 158  Extravagant_Spending_Adults
# 159  Extravagant_Spending_Adults
# 160       Modest_Spending_Seniors
# 161  Extravagant_Spending_Adults
# 162           High_Spending_Youth
# 163  Extravagant_Spending_Adults
# 164      Middle_Aged_low_Spenders
# 165  Extravagant_Spending_Adults
# 166      Middle_Aged_low_Spenders
# 167  Extravagant_Spending_Adults
# 168  Extravagant_Spending_Adults
# 169  Extravagant_Spending_Adults
# 170  Extravagant_Spending_Adults
# 171           High_Spending_Youth
# 172  Extravagant_Spending_Adults
# 173  Extravagant_Spending_Adults
# 174      Middle_Aged_low_Spenders
# 175  Extravagant_Spending_Adults
# 176       Modest_Spending_Seniors
# 177           High_Spending_Youth
# 178       Modest_Spending_Seniors
# 179  Extravagant_Spending_Adults
# 180  Extravagant_Spending_Adults
# 181  Extravagant_Spending_Adults
# 182      Middle_Aged_low_Spenders
# 183  Extravagant_Spending_Adults
# 184  Extravagant_Spending_Adults
# 185  Extravagant_Spending_Adults
# 186      Middle_Aged_low_Spenders
# 187           High_Spending_Youth
# 188  Extravagant_Spending_Adults
# 189  Extravagant_Spending_Adults
# 190  Extravagant_Spending_Adults
# 191  Extravagant_Spending_Adults
# 192  Extravagant_Spending_Adults
# 193  Extravagant_Spending_Adults
# 194      Middle_Aged_low_Spenders
# 195  Extravagant_Spending_Adults
# 196      Middle_Aged_low_Spenders
# 197  Extravagant_Spending_Adults
# 198  Extravagant_Spending_Adults
# 199  Extravagant_Spending_Adults

# %%
# plot the clusters
from matplotlib.patches import Patch
colors = ['yellow', 'purple', 'green', 'blue']
labels = ['High_Spending_Youth', 'Extravagant_Spending_Adults ', 'Middle_Aged_low_Spenders','Modest_Spending_Seniors']
plt.scatter( clustering_dataset.loc[:, ['Age']],clustering_dataset.loc[:, ['Spending_Score']], c=clustering_dataset['Cluster_label'], cmap="viridis")
plt.title("K-Means Cluster Results of Age vs Spending_Score")
plt.xlabel("Age")
plt.ylabel("Spending Score")
plt.legend([3],prop={'size': 12}, bbox_to_anchor=(1.05, 1), loc='upper left')
legend_patches = [Patch(color=color, label=label) for color, label in zip(colors,labels)]

# Add a legend
plt.legend(handles=legend_patches)





plt.show()

# %%
#Save the model file and interfaces for scoring
import pickle

# Save the StandardScaler object to a file
with open('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Output/standard_scalar.pkl', 'wb') as f:
    pickle.dump(scaler, f)
    
# Save the KMeans object to a file
with open('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Output/kmeans.pkl', 'wb') as f:
    pickle.dump(kmeans, f)

# %%
# Load the StandardScaler object from the file
with open('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Output/standard_scalar.pkl', 'rb') as f:
    scaler_loaded = pickle.load(f)
    
with open('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Output/kmeans.pkl', 'rb') as f:
    kmeans_loaded = pickle.load(f)

# %%
#read the input data
new_data = pd.read_csv('/Users/ankit/Data-Science/MTN Group/Customer Spend Behvarioural analytics/Input/Mall_customers.csv')

gender_map ={'Male':0,'Female':1}
new_data['Gender']=new_data['Genre'].map(gender_map)

variables_to_scale = ['Age','Annual_Income_(k$)','Spending_Score']

# Transform the dataset to standardized values
X_std = scaler_loaded.transform(clustering_dataset[variables_to_scale])


Age_scaled = X_std[:,0]
Annual_income_scaled = X_std[:,1]
Spending_score_scaled = X_std[:,2]

new_data['Age_scaled'] = Age_scaled
new_data['Annual_income_scaled'] = Annual_income_scaled
new_data['Spending_score_scaled'] = Spending_score_scaled

# %%
#clutering columns
clustering_columns=['Age','Age_scaled','Annual_income_scaled','Spending_score_scaled']
labels = kmeans_loaded.predict(new_data[clustering_columns])

# %%
new_data['Cluster_label']=labels
#Create cluster profile mapping
cluster_map = {0:'Extravagant_Spending_Adults '
               ,1:'Modest_Spending_Seniors'
               ,2:'Middle_Aged_low_Spenders'
               ,3:'High_Spending_Youth'}

new_data['Cluster_name']= new_data['Cluster_label'].map(cluster_map)

# %%
new_data['Cluster_name'].value_counts()
# Out:
# Extravagant_Spending_Adults     74
# High_Spending_Youth             50
# Middle_Aged_low_Spenders        47
# Modest_Spending_Seniors         29
# Name: Cluster_name, dtype: int64

# %% [markdown]
# #### End of Script

# %% [markdown]
# ----------------------------------------
